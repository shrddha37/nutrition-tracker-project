# %%
BASE = "/home/jovyan/work"
RAW = f"{BASE}/data/raw"
BRONZE = f"{BASE}/parquet/bronze"

# %%
from pyspark.sql.functions import current_timestamp, lit
import os

def load_to_bronze(name):
    path = f"{RAW}/{name}.csv"
    if not os.path.exists(path):
        print(f"⚠️ File not found: {path}")
        return
    df = (
        spark.read.format("csv")
        .option("header", "true")
        .option("inferSchema", "true")
        .load(path)
        .withColumn("_ingest_ts", current_timestamp())
        .withColumn("_source", lit(name))
    )
    df.write.mode("overwrite").parquet(f"{BRONZE}/{name}")
    print(f"✅ {name} → bronze written ({df.count()} rows)")

# %%
# 1) Run ingestion for each file
for name in ["users", "food_items", "intake_logs", "water_logs", "mood_logs"]:
    load_to_bronze(name)
# Out:
# ✅ users → bronze written (60 rows)
# ✅ food_items → bronze written (20 rows)
# ✅ intake_logs → bronze written (150 rows)
# ✅ water_logs → bronze written (120 rows)
# ✅ mood_logs → bronze written (80 rows)

# %%
# 2) Peek & schema check 
datasets = ["users","food_items","intake_logs","water_logs","mood_logs"] 
for t in datasets: 
  try: 
    df = spark.read.parquet(f"{BRONZE}/{t}") 
    print(f"\n=== bronze/{t} ===") 
    print("rows:", df.count()) 
    df.printSchema() 
    df.show(5, truncate=False) 
  except Exception as e: 
    print(f"Skipped {t}: {e}")
# Out:
# === bronze/users ===
# rows: 60
# root
#  |-- user_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- dob: date (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- goals: string (nullable = true)
#  |-- bmi: double (nullable = true)
#  |-- _ingest_ts: timestamp (nullable = true)
#  |-- _source: string (nullable = true)
#
# +-------+---------+------+----------+---+-----+----+-------------------------+-------+
# |user_id|name     |gender|dob       |age|goals|bmi |_ingest_ts               |_source|
# +-------+---------+------+----------+---+-----+----+-------------------------+-------+
# |1      |Krishna  |F     |2003-08-17|22 |NULL |24.6|2025-10-30 09:20:48.78916|users  |
# |2      |Radharani|F     |2002-03-31|23 |NULL |20.0|2025-10-30 09:20:48.78916|users  |
# |3      |Kishori  |F     |2000-10-01|25 |NULL |19.6|2025-10-30 09:20:48.78916|users  |
# |4      |Jagannath|M     |1999-11-15|25 |NULL |21.3|2025-10-30 09:20:48.78916|users  |
# |5      |Vitthal  |F     |2002-09-06|23 |NULL |18.8|2025-10-30 09:20:48.78916|users  |
# +-------+---------+------+----------+---+-----+----+-------------------------+-------+
# only showing top 5 rows
#
#
# === bronze/food_items ===
# rows: 20
# root
#  |-- food_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- serving_unit: string (nullable = true)
#  |-- protein_g: double (nullable = true)
#  |-- carbs_g: double (nullable = true)
#  |-- fat_g: double (nullable = true)
#  |-- kcal_per_serving: double (nullable = true)
#  |-- _ingest_ts: timestamp (nullable = true)
#  |-- _source: string (nullable = true)
#
# +-------+-------+------------+---------+-------+-----+----------------+--------------------------+----------+
# |food_id|name   |serving_unit|protein_g|carbs_g|fat_g|kcal_per_serving|_ingest_ts                |_source   |
# +-------+-------+------------+---------+-------+-----+----------------+--------------------------+----------+
# |101    |Banana |1 pc        |3.0      |29.3   |7.3  |273.0           |2025-10-30 09:20:51.822911|food_items|
# |102    |Milk   |250 ml      |7.8      |45.1   |7.7  |271.0           |2025-10-30 09:20:51.822911|food_items|
# |103    |Paneer |100 g       |16.4     |22.1   |14.7 |240.0           |2025-10-30 09:20:51.822911|food_items|
# |104    |Oats   |50 g        |2.4      |52.4   |11.0 |139.0           |2025-10-30 09:20:51.822911|food_items|
# |105    |Almonds|10 pcs      |6.1      |55.5   |16.2 |277.0           |2025-10-30 09:20:51.822911|food_items|
# +-------+-------+------------+---------+-------+-----+----------------+--------------------------+----------+
# only showing top 5 rows
#
#
# === bronze/intake_logs ===
# rows: 150
# root
#  |-- log_id: integer (nullable = true)
#  |-- user_id: integer (nullable = true)
#  |-- food_id: integer (nullable = true)
#  |-- servings: double (nullable = true)
#  |-- taken_at: timestamp (nullable = true)
#  |-- meal_type: string (nullable = true)
#  |-- calories: double (nullable = true)
#  |-- _ingest_ts: timestamp (nullable = true)
#  |-- _source: string (nullable = true)
#
# +------+-------+-------+--------+-------------------+---------+--------+--------------------------+-----------+
# |log_id|user_id|food_id|servings|taken_at           |meal_type|calories|_ingest_ts                |_source    |
# +------+-------+-------+--------+-------------------+---------+--------+--------------------------+-----------+
# |1001  |50     |101    |1.5     |2025-10-23 22:33:02|breakfast|409.5   |2025-10-30 09:20:54.894116|intake_logs|
# |1002  |4      |119    |2.0     |2025-10-12 03:08:16|dinner   |590.0   |2025-10-30 09:20:54.894116|intake_logs|
# |1003  |31     |104    |2.0     |2025-10-14 23:04:28|snack    |278.0   |2025-10-30 09:20:54.894116|intake_logs|
# |1004  |39     |104    |0.5     |2025-10-26 20:56:37|dinner   |69.5    |2025-10-30 09:20:54.894116|intake_logs|
# |1005  |47     |110    |0.5     |2025-10-05 17:22:21|snack    |124.5   |2025-10-30 09:20:54.894116|intake_logs|
# +------+-------+-------+--------+-------------------+---------+--------+--------------------------+-----------+
# only showing top 5 rows
#
#
# === bronze/water_logs ===
# rows: 120
# root
#  |-- user_id: integer (nullable = true)
#  |-- ml: integer (nullable = true)
#  |-- taken_at: timestamp (nullable = true)
#  |-- _ingest_ts: timestamp (nullable = true)
#  |-- _source: string (nullable = true)
#
# +-------+----+-------------------+--------------------------+----------+
# |user_id|ml  |taken_at           |_ingest_ts                |_source   |
# +-------+----+-------------------+--------------------------+----------+
# |55     |300 |2025-10-21 11:41:03|2025-10-30 09:20:57.723123|water_logs|
# |13     |1000|2025-10-02 20:42:22|2025-10-30 09:20:57.723123|water_logs|
# |14     |700 |2025-10-15 07:05:33|2025-10-30 09:20:57.723123|water_logs|
# |17     |300 |2025-10-18 05:36:39|2025-10-30 09:20:57.723123|water_logs|
# |36     |300 |2025-10-16 11:13:23|2025-10-30 09:20:57.723123|water_logs|
# +-------+----+-------------------+--------------------------+----------+
# only showing top 5 rows
#
#
# === bronze/mood_logs ===
# rows: 80
# root
#  |-- user_id: integer (nullable = true)
#  |-- mood: string (nullable = true)
#  |-- taken_at: timestamp (nullable = true)
#  |-- _ingest_ts: timestamp (nullable = true)
#  |-- _source: string (nullable = true)
#
# +-------+--------+-------------------+--------------------------+---------+
# |user_id|mood    |taken_at           |_ingest_ts                |_source  |
# +-------+--------+-------------------+--------------------------+---------+
# |10     |happy   |2025-10-10 11:09:20|2025-10-30 09:20:59.999813|mood_logs|
# |11     |neutral |2025-10-20 16:52:16|2025-10-30 09:20:59.999813|mood_logs|
# |23     |stressed|2025-10-28 21:20:01|2025-10-30 09:20:59.999813|mood_logs|
# |31     |focused |2025-10-22 07:40:41|2025-10-30 09:20:59.999813|mood_logs|
# |34     |tired   |2025-10-27 05:05:08|2025-10-30 09:20:59.999813|mood_logs|
# +-------+--------+-------------------+--------------------------+---------+
# only showing top 5 rows
